# %%
from huggingface_hub import hf_hub_download   # docs: hf_hub_download() guide :contentReference[oaicite:5]{index=5}
import pandas as pd, re, pathlib
import os 

# 1) grab the CSV (~400 MB) once; HF Hub will cache it
cat_path = hf_hub_download(
    repo_id="imageomics/TreeOfLife-10M",
    filename="metadata/catalog.csv",
    repo_type="dataset",
    token = True
)

df = pd.read_csv(cat_path)

phylum_family_list = os.listdir('../cleaned_chordata_images/val')

# 2) normalise your list: drop .DS_Store and strip prefix
targets = [re.sub(r"^chordata_", "", f).lower()
           for f in phylum_family_list if not f.startswith(".")]



# 3) pick only Chordata rows AND families you care about
mask = (df.phylum == "Chordata") & df.family.str.lower().isin(targets)
subset_families = df.loc[mask].copy()

print(f"{len(subset_families):,} matching images")
subset_families.to_csv("chordate_families_subset.csv", index=False)

# delete the original dataframe to clear up RAM space
del df

# %%
subset_families = pd.read_csv('chordate_families_subset.csv')

subset_families.head()
# Out:
# /var/folders/nj/p20z0h9x3ssf6ll0_cdhh2yc0000gn/T/ipykernel_27377/3516065072.py:1: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   subset_families = pd.read_csv('chordate_families_subset.csv')
#          split                         treeoflife_id  eol_content_id  \
# 0  train_small  a8b544e8-d02c-4b52-a267-8ffdf34e7bd0      30013717.0
# 1  train_small  b7512b6c-c4a7-4f8e-b141-5a62489e2781      28486176.0
# 2  train_small  acc400f5-9b01-4aae-90a8-e65b591f0d7a      21162185.0
# 3  train_small  fa231162-eb5c-4803-937d-d52221c5ad79      22392467.0
# 4  train_small  26ad8438-dbbf-41e7-9d4b-8159a6991604      29586658.0
#
#    eol_page_id  bioscan_part  bioscan_filename inat21_filename  \
# 0   65422934.0           NaN               NaN             NaN
# 1   59052146.0           NaN               NaN             NaN
# 2   49157640.0           NaN               NaN             NaN
# 3    1254561.0           NaN               NaN             NaN
# 4   46559477.0           NaN               NaN             NaN
#
#   inat21_cls_name  inat21_cls_num   kingdom    phylum     class        order  \
# 0             NaN             NaN  Animalia  Chordata      Aves  Apodiformes
# 1             NaN             NaN  Animalia  Chordata  Reptilia     Squamata
# 2             NaN             NaN  Animalia  Chordata  Reptilia     Squamata
# 3             NaN             NaN  Animalia  Chordata  Reptilia   Testudines
# 4             NaN             NaN  Animalia  Chordata  Reptilia   Testudines
#
#             family         genus   species                      common
# 0      Trochilidae      Amazilia  franciae              andean emerald
# 1  Diplodactylidae       Bavayia   cyclura              Forest Bavayia
# 2      Dactyloidae        Anolis  schiedii             Schiede's Anole
# 3     Testudinidae       Testudo  hermanni  Eastern Hermann's Tortoise
# 4      Cheloniidae  Lepidochelys  olivacea                Olive Ridley

# %%
# IDs of families that we need
subset_ids = subset_families.treeoflife_id.tolist()

# %%
from huggingface_hub import hf_hub_download

licenses_path = hf_hub_download(
    repo_id   = "imageomics/TreeOfLife-10M",
    filename  = "metadata/licenses.csv",
    repo_type = "dataset",      # tells HF you want a dataset file :contentReference[oaicite:0]{index=0}
    token     = True,           # uses your cached HF token
    force_download = False      # set True to re‑fetch a corrupt cache
)


df = pd.read_csv(licenses_path)           # load into DataFrame :contentReference[oaicite:1]{index=1}
# Suppose your IDs are integers in a Python set:

# Filter only the rows you need
subset = df[df["treeoflife_id"].isin(subset_ids)]   # Boolean mask :contentReference[oaicite:2]{index=2}

# Extract the EOL full‑size URLs
urls = subset["eol_full_size_copy_url"].tolist()
# Out:
# licenses.csv:   0%|          | 0.00/2.22G [00:00<?, ?B/s]

# %%
subset.head()
# Out:
#                            treeoflife_id  eol_content_id  eol_page_id  \
# 5   df4a72dc-42fb-4fdc-ae44-2c8c5ef0a1d3      21938526.0    1267996.0
# 40  b5a32e39-fed8-4f5b-9afc-bb16a217852a      22769563.0    1055234.0
# 48  89bcd3e0-c311-49ab-b95a-c7d9b5feba4c      14160409.0    1056414.0
# 60  347fee52-cf82-4043-b38b-0cece69e6d71      28678100.0   59052132.0
# 93  ddd8806a-4fac-4f29-a1ec-8f6d85449956      22694533.0     790725.0
#
#                                  md5  \
# 5   b22abb0f4686e7195cc8bdbf0c8f79ab
# 40  6b44b5632a59d45adae1ea10c18884e1
# 48  d85c4ff1e152ca95cb536f8c2ad369f3
# 60  3c091da6690c25d38595980081ed7048
# 93  9f210b8d658a0b32ee9f04a890d52dc8
#
#                                     medium_source_url  \
# 5   https://inaturalist-open-data.s3.amazonaws.com...
# 40  https://inaturalist-open-data.s3.amazonaws.com...
# 48  https://farm8.staticflickr.com/7270/7846311014...
# 60  http://mczbase.mcz.harvard.edu/specimen_images...
# 93  https://inaturalist-open-data.s3.amazonaws.com...
#
#                                eol_full_size_copy_url     license_name  \
# 5   https://content.eol.org/data/media/5b/03/ac/18...     cc-by-nc-4.0
# 40  https://content.eol.org/data/media/5f/9a/11/18...     cc-by-nc-4.0
# 48  https://content.eol.org/data/media/d7/c2/f8/54...     cc-by-sa-2.0
# 60  https://content.eol.org/data/media/c7/f2/00/26...  cc-by-nc-sa-3.0
# 93  https://content.eol.org/data/media/5d/96/a2/18...     cc-by-nc-4.0
#
#                                       copyright_owner  \
# 5                                            dianne49
# 40                                    mobinkargarfard
# 48                                Cristopher Gonzalez
# 60  Museum of Comparative Zoology, Harvard University
# 93                              Daniel Montoya Ferrer
#
#                                          license_link         title
# 5      https://creativecommons.org/licenses/by-nc/4.0  not provided
# 40     https://creativecommons.org/licenses/by-nc/4.0  not provided
# 48     https://creativecommons.org/licenses/by-sa/2.0  not provided
# 60  https://creativecommons.org/licenses/by-nc-sa/3.0  not provided
# 93     https://creativecommons.org/licenses/by-nc/4.0  not provided

# %%
display(subset_families.info())
display(subset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052342 entries, 0 to 1052341
# Data columns (total 17 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   split             1052342 non-null  object
#  1   treeoflife_id     1052342 non-null  object
#  2   eol_content_id    613585 non-null   float64
#  3   eol_page_id       613585 non-null   float64
#  4   bioscan_part      0 non-null        float64
#  5   bioscan_filename  0 non-null        float64
#  6   inat21_filename   438757 non-null   object
#  7   inat21_cls_name   438757 non-null   object
#  8   inat21_cls_num    438757 non-null   float64
#  9   kingdom           1052342 non-null  object
#  10  phylum            1052342 non-null  object
#  11  class             1052342 non-null  object
#  12  order             1052342 non-null  object
#  13  family            1052342 non-null  object
#  14  genus             1047704 non-null  object
#  15  species           1034700 non-null  object
#  16  common            1052342 non-null  object
# dtypes: float64(5), object(12)
# memory usage: 136.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 560555 entries, 5 to 6219617
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   treeoflife_id           560555 non-null  object
#  1   eol_content_id          560555 non-null  float64
#  2   eol_page_id             560555 non-null  float64
#  3   md5                     560555 non-null  object
#  4   medium_source_url       560555 non-null  object
#  5   eol_full_size_copy_url  560555 non-null  object
#  6   license_name            560555 non-null  object
#  7   copyright_owner         560555 non-null  object
#  8   license_link            559763 non-null  object
#  9   title                   560555 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 47.0+ MB
# None

# %%
# Clean and standardize the treeoflife_id in both DataFrames
subset['treeoflife_id'] = subset['treeoflife_id'].astype(str).str.strip()
subset_families['treeoflife_id'] = subset_families['treeoflife_id'].astype(str).str.strip()
# Out:
# /var/folders/nj/p20z0h9x3ssf6ll0_cdhh2yc0000gn/T/ipykernel_27377/1790806881.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['treeoflife_id'] = subset['treeoflife_id'].astype(str).str.strip()

# %%
df_url_family = pd.merge(subset, 
                        subset_families[['treeoflife_id', 'phylum', 'family']],
                        on='treeoflife_id',
                        how='inner')

# %%
df_url_family
# Out:
#                                treeoflife_id  eol_content_id  eol_page_id  \
# 0       df4a72dc-42fb-4fdc-ae44-2c8c5ef0a1d3      21938526.0    1267996.0
# 1       b5a32e39-fed8-4f5b-9afc-bb16a217852a      22769563.0    1055234.0
# 2       89bcd3e0-c311-49ab-b95a-c7d9b5feba4c      14160409.0    1056414.0
# 3       347fee52-cf82-4043-b38b-0cece69e6d71      28678100.0   59052132.0
# 4       ddd8806a-4fac-4f29-a1ec-8f6d85449956      22694533.0     790725.0
# ...                                      ...             ...          ...
# 613580  50c7ae23-bbb9-474d-8a5a-6260f2ca42bc       8910880.0   45511280.0
# 613581  91c0c7ec-0a41-4653-bd20-e69f878c9624      22092768.0   45509111.0
# 613582  41a74f83-50cf-4d1e-81bf-6cdf16e09c95      21697348.0     795204.0
# 613583  e8a8cbf0-adc9-4310-948c-d71d7029102e      29560128.0   45509305.0
# 613584  0aa8c9df-9210-4b4f-ac1f-a2eff6a185a7      21355376.0   45512448.0
#
#                                      md5  \
# 0       b22abb0f4686e7195cc8bdbf0c8f79ab
# 1       6b44b5632a59d45adae1ea10c18884e1
# 2       d85c4ff1e152ca95cb536f8c2ad369f3
# 3       3c091da6690c25d38595980081ed7048
# 4       9f210b8d658a0b32ee9f04a890d52dc8
# ...                                  ...
# 613580  6dd0764f0dc60cea12f9712cbeb861f7
# 613581  3233e26c2c3c269ebea2b00f14720973
# 613582  5ed8a3241679bf01c9094f4b5946bfdd
# 613583  f4d297f0693524f08be61eec8b8db6d3
# 613584  c52040f9bc06438922357bc956f1d582
#
#                                         medium_source_url  \
# 0       https://inaturalist-open-data.s3.amazonaws.com...
# 1       https://inaturalist-open-data.s3.amazonaws.com...
# 2       https://farm8.staticflickr.com/7270/7846311014...
# 3       http://mczbase.mcz.harvard.edu/specimen_images...
# 4       https://inaturalist-open-data.s3.amazonaws.com...
# ...                                                   ...
# 613580  http://calphotos.berkeley.edu/imgs/512x768/666...
# 613581  https://inaturalist-open-data.s3.amazonaws.com...
# 613582  https://inaturalist-open-data.s3.amazonaws.com...
# 613583  https://upload.wikimedia.org/wikipedia/commons...
# 613584  https://inaturalist-open-data.s3.amazonaws.com...
#
#                                    eol_full_size_copy_url     license_name  \
# 0       https://content.eol.org/data/media/5b/03/ac/18...     cc-by-nc-4.0
# 1       https://content.eol.org/data/media/5f/9a/11/18...     cc-by-nc-4.0
# 2       https://content.eol.org/data/media/d7/c2/f8/54...     cc-by-sa-2.0
# 3       https://content.eol.org/data/media/c7/f2/00/26...  cc-by-nc-sa-3.0
# 4       https://content.eol.org/data/media/5d/96/a2/18...     cc-by-nc-4.0
# ...                                                   ...              ...
# 613580  https://content.eol.org/data/media/88/1f/4e/7....  cc-by-nc-sa-3.0
# 613581  https://content.eol.org/data/media/76/51/fc/18...     cc-by-nc-4.0
# 613582  https://content.eol.org/data/media/6c/df/c0/18...     cc-by-nc-4.0
# 613583  https://content.eol.org/data/media/64/5d/8f/50...     cc-by-sa-3.0
# 613584  https://content.eol.org/data/media/65/67/23/18...     cc-by-nc-4.0
#
#                                           copyright_owner  \
# 0                                                dianne49
# 1                                         mobinkargarfard
# 2                                     Cristopher Gonzalez
# 3       Museum of Comparative Zoology, Harvard University
# 4                                   Daniel Montoya Ferrer
# ...                                                   ...
# 613580                2015 California Academy of Sciences
# 613581                        Dra. Laura Elvia Uribe Lara
# 613582                                       Ray Turnbull
# 613583                                    Andreas Eichler
# 613584                                     Attila Steiner
#
#                                              license_link         title  \
# 0          https://creativecommons.org/licenses/by-nc/4.0  not provided
# 1          https://creativecommons.org/licenses/by-nc/4.0  not provided
# 2          https://creativecommons.org/licenses/by-sa/2.0  not provided
# 3       https://creativecommons.org/licenses/by-nc-sa/3.0  not provided
# 4          https://creativecommons.org/licenses/by-nc/4.0  not provided
# ...                                                   ...           ...
# 613580  https://creativecommons.org/licenses/by-nc-sa/3.0  not provided
# 613581     https://creativecommons.org/licenses/by-nc/4.0  not provided
# 613582     https://creativecommons.org/licenses/by-nc/4.0  not provided
# 613583     https://creativecommons.org/licenses/by-sa/3.0  not provided
# 613584     https://creativecommons.org/licenses/by-nc/4.0  not provided
#
#           phylum           family
# 0       Chordata       Columbidae
# 1       Chordata       Colubridae
# 2       Chordata        Viperidae
# 3       Chordata       Gekkonidae
# 4       Chordata  Phrynosomatidae
# ...          ...              ...
# 613580  Chordata   Procellariidae
# 613581  Chordata         Rallidae
# 613582  Chordata        Scincidae
# 613583  Chordata          Laridae
# 613584  Chordata      Trochilidae
#
# [613585 rows x 12 columns]

# %%
#!/usr/bin/env python3
"""
flatten_chordata.py

For each directory named chordata_<family>/pictures, move all files
up one level into chordata_<family>/ and delete the empty pictures/ folder.
"""

import shutil
from pathlib import Path

def flatten_chordata(root: Path) -> None:
    """
    Walks through each chordata_<family>/pictures folder under `root`,
    moves its files up to chordata_<family>/, and removes the pictures folder.
    """
    # Glob for all 'pictures' subdirectories in any chordata_* folder
    for pics_dir in root.glob("additional_data/chordata_*/pictures"):
        if not pics_dir.is_dir():
            continue

        parent_dir = pics_dir.parent  # chordata_<family> directory
        print(f"▸ Processing {pics_dir} → {parent_dir}")

        # Move each file from pictures/ to the parent directory
        for item in pics_dir.iterdir():
            if item.is_file():
                dest = parent_dir / item.name
                print(f"    moving {item.name} → {dest}")
                shutil.move(str(item), str(dest))

        # Remove the now-empty pictures directory
        try:
            pics_dir.rmdir()
            print(f"✓ Removed empty folder {pics_dir}")
        except OSError as e:
            print(f"⚠️  Could not remove {pics_dir}: {e}")

if __name__ == "__main__":
    import argparse

    p = argparse.ArgumentParser(
        description="Flatten chordata_<family>/pictures → chordata_<family>/"
    )
    p.add_argument(
        "--root",
        type=Path,
        default=Path.cwd(),
        help="Root directory containing chordata_<family> folders"
    )
    args = p.parse_args()
    flatten_chordata(args.root)
# Out:
# usage: ipykernel_launcher.py [-h] [--root ROOT]
# ipykernel_launcher.py: error: unrecognized arguments: --f=/Users/svengoerdes/Library/Jupyter/runtime/kernel-v3c4185bef1aef851e8e4ec3e9c810bf57462f606f.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /Users/svengoerdes/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import os
import requests
import pandas as pd
import time # Import the time module
from tqdm.notebook import tqdm # Use 'from tqdm import tqdm' if not in a Jupyter environment

# --- Configuration ---
# !!! IMPORTANT: Replace 'your_url_column_name' with the actual column name containing the image URLs !!!
image_url_column = 'eol_full_size_copy_url' # Assuming this is correct from context
# Assume df_url_family is your DataFrame
# df_url_family = ...

base_output_dir = "additional_data"
images_per_family = 10
request_delay_seconds = 1 # Added: Delay between requests (in seconds)

already_pulled = [
    'Columbidae',
    'Colubridae',
    'Viperidae',
    'Gekkonidae',
    'Phrynosomatidae',
    'Labridae',
    'Spheniscidae',
    'Otariidae',
    'Strigidae',
    'Chaetodontidae',
    'Soricidae'
]
# --- End Configuration ---

# Make sure the DataFrame and necessary columns exist
if 'df_url_family' not in locals():
    print("Error: DataFrame 'df_url_family' not found.")
elif not all(col in df_url_family.columns for col in ['family', 'treeoflife_id', image_url_column]):
    print(f"Error: DataFrame 'df_url_family' must contain 'family', 'treeoflife_id', and '{image_url_column}' columns.")
else:
    os.makedirs(base_output_dir, exist_ok=True)
    unique_families = df_url_family['family'].dropna().unique()
    
    # remvoe out of list that already have been pulled
    unique_families = [family for family in unique_families if family not in already_pulled]
    print(f"Found {len(unique_families)} unique families.")

    for family in tqdm(unique_families, desc="Processing families"):
        family_lower = str(family).lower().replace(' ', '_')
        print(f"\nProcessing family: {family}")

        target_dir = os.path.join(base_output_dir, f"chordata_{family_lower}")
        os.makedirs(target_dir, exist_ok=True)

        family_df = df_url_family[
            (df_url_family['family'] == family) &
            (df_url_family[image_url_column].notna()) &
            (df_url_family[image_url_column] != '')
        ].copy()

        samples_df = family_df.head(images_per_family)

        if samples_df.empty:
            print(f"  No images with valid URLs found for family: {family}")
            continue

        print(f"  Attempting to download {len(samples_df)} images for {family}...")

        downloaded_count = 0
        for index, row in samples_df.iterrows():
            image_url = row[image_url_column]
            tree_id = row['treeoflife_id']

            try:
                file_extension = os.path.splitext(image_url.split('?')[0])[-1]
                if not file_extension or len(file_extension) > 5:
                     file_extension = '.jpg'
            except Exception:
                file_extension = '.jpg'

            filename = f"{tree_id}{file_extension}"
            output_path = os.path.join(target_dir, filename)

            if os.path.exists(output_path):
                downloaded_count += 1
                continue

            try:
                response = requests.get(image_url, stream=True, timeout=20)
                response.raise_for_status() # Raise HTTPError for bad responses (4xx or 5xx)

                with open(output_path, 'wb') as f:
                    for chunk in response.iter_content(chunk_size=8192):
                        f.write(chunk)
                downloaded_count += 1

            except requests.exceptions.HTTPError as e:
                 # Specifically handle 429 errors if needed, or just print general HTTP errors
                 if e.response.status_code == 429:
                     print(f"  Rate limit hit (429) for {image_url}. Consider increasing delay.")
                     # Optional: Implement retry logic here later if needed
                 else:
                     print(f"  HTTP Error downloading {image_url}: {e}")
                 if os.path.exists(output_path):
                     try: os.remove(output_path)
                     except OSError: pass
            except requests.exceptions.Timeout:
                print(f"  Timeout downloading {image_url}")
            except requests.exceptions.RequestException as e:
                print(f"  Error downloading {image_url}: {e}")
                if os.path.exists(output_path):
                    try: os.remove(output_path)
                    except OSError: pass
            except IOError as e:
                print(f"  Error saving file {output_path}: {e}")
            except Exception as e:
                print(f"  An unexpected error occurred for {image_url} ({output_path}): {e}")

            # --- Add delay ---
            # Wait for the specified amount of time before the next request
            time.sleep(request_delay_seconds)
            # --- End delay ---


        print(f"  Finished for {family}. Found/Downloaded {downloaded_count}/{len(samples_df)} requested images.")

    print("\n--- Image download process complete ---")
# Out:
# Found 150 unique families.
# Processing families:   0%|          | 0/150 [00:00<?, ?it/s]
# Processing family: Scincidae
#   Attempting to download 10 images for Scincidae...
#   Finished for Scincidae. Found/Downloaded 10/10 requested images.
#
# Processing family: Bovidae
#   Attempting to download 10 images for Bovidae...
#   Finished for Bovidae. Found/Downloaded 10/10 requested images.
#
# Processing family: Dactyloidae
#   Attempting to download 10 images for Dactyloidae...
#   Finished for Dactyloidae. Found/Downloaded 10/10 requested images.
#
# Processing family: Anatidae
#   Attempting to download 10 images for Anatidae...
#   Finished for Anatidae. Found/Downloaded 10/10 requested images.
#
# Processing family: Phyllomedusidae
#   Attempting to download 10 images for Phyllomedusidae...
#   Finished for Phyllomedusidae. Found/Downloaded 10/10 requested images.
#
# Processing family: Muscicapidae
#   Attempting to download 10 images for Muscicapidae...
#   Finished for Muscicapidae. Found/Downloaded 10/10 requested images.
#
# Processing family: Thraupidae
#   Attempting to download 10 images for Thraupidae...
#   Finished for Thraupidae. Found/Downloaded 10/10 requested images.
#
# Processing family: Balaenopteridae
#   Attempting to download 10 images for Balaenopteridae...
#   Finished for Balaenopteridae. Found/Downloaded 10/10 requested images.
#
# Processing family: Scombridae
#   Attempting to download 10 images for Scombridae...
#   Finished for Scombridae. Found/Downloaded 10/10 requested images.
#
# Processing family: Percidae
#   Attempting to download 10 images for Percidae...
#   Finished for Percidae. Found/Downloaded 10/10 requested images.
#
# Processing family: Scolopacidae
#   Attempting to download 10 images for Scolopacidae...
#   Finished for Scolopacidae. Found/Downloaded 10/10 requested images.
#
# Processing family: Ardeidae
#   Attempting to download 10 images for Ardeidae...
#   Rate limit hit (429) for https://content.eol.org/data/media/80/d8/b2/18.f4f52cd7d643cd6a1cae2f86449c4d88.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/57/2d/ff/509.20d5f83cb4f5e7556cbebad276a49628.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/c6/70/f1/269.229220.jpg. Consider increasing delay.
#   Finished for Ardeidae. Found/Downloaded 7/10 requested images.
#
# Processing family: Odontophoridae
#   Attempting to download 10 images for Odontophoridae...
#   Rate limit hit (429) for https://content.eol.org/data/media/71/79/dd/18.9ee32f7ff274292b4e7d3e2a18b19ee1.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media
ae...
#   Rate limit hit (429) for https://content.eol.org/data/media/16/2a/66/537.60b230d37661ace56e0036af2096dd7e.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/c4/b7/77/15.FB-pic-638-51236.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/55/11/32/18.0023bfde94696132a5458a27d526d910.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/58/8a/34/509.4e8c77a15feb310d664229f96f2c71ad.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/00/18/c7/8.6001824514.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/16/a4/37/537.7dac56584d973564d2c281dc5697bb4f.jpg. Consider increasing delay.
#   Finished for Hexanchidae. Found/Downloaded 4/10 requested images.
#
# Processing family: Latimeriidae
#   Attempting to download 10 images for Latimeriidae...
#   Rate limit hit (429) for https://content.eol.org/data/media/59/30/a5/509.1a2ac8d5ffd4819cced05b28461fcc8f.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/57/6f/ef/509.88288b2b23a40a4a472d94647d952542.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/59/30/a4/509.ad731b91845e3cc45d792b9b6c51f419.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/5f/88/ef/509.f989f16c10fbc953865bee49195f48b7.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/55/3f/77/509.05b454a86eb651bc35f0d2b0f03dd564.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/ed/18/7a/509.ed6ad94b913f8a3de1158430cf64ce00.jpg. Consider increasing delay.
#   Finished for Latimeriidae. Found/Downloaded 4/10 requested images.
#
# Processing family: Gavialidae
#   Attempting to download 4 images for Gavialidae...
#   Rate limit hit (429) for https://content.eol.org/data/media/85/b4/cd/7.CalPhotos_0000_0000_0413_0686.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/1c/2b/b7/8.6309777240.jpg. Consider increasing delay.
#   Finished for Gavialidae. Found/Downloaded 2/4 requested images.
#
# Processing family: Pontoporiidae
#   Attempting to download 4 images for Pontoporiidae...
#   Rate limit hit (429) for https://content.eol.org/data/media/b5/51/6e/680.19671208.jpg. Consider increasing delay.
#   Rate limit hit (429) for https://content.eol.org/data/media/84/f7/c6/7.CalPhotos_0000_0000_0115_0008.jpg. Consider increasing delay.
#   Finished for Pontoporiidae. Found/Downloaded 2/4 requested images.
#
# --- Image download process complete ---

# %%
from datasets import load_dataset

ds = load_dataset(
    "imageomics/TreeOfLife-10M",
    split="train",            # or "train"
    streaming=True,         # returns IterableDataset :contentReference[oaicite:4]{index=4}
    token=True              # uses your cached HF token
)
# Out:
# Resolving data files:   0%|          | 0/72 [00:00<?, ?it/s]

# %%
filtered = ds.filter(lambda ex: ex["treeoflife_id"] in id_list)

# %%
# subset['phylum_family'] = subset['phylum'].lower() + '_' + subset['family'].lower()

subset['phylum_family'] = subset.apply(lambda row: row['phylum'].lower() + '_' + row['family'].lower(), axis = 1)

# %%
subset['__url__']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '__url__'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 subset['__url__']
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: '__url__'

# %%
subset.head(2)
# Out:
#           split                         treeoflife_id  eol_content_id  \
# 13  train_small  a8b544e8-d02c-4b52-a267-8ffdf34e7bd0      30013717.0
# 21  train_small  b7512b6c-c4a7-4f8e-b141-5a62489e2781      28486176.0
#
#     eol_page_id  bioscan_part bioscan_filename inat21_filename  \
# 13   65422934.0           NaN              NaN             NaN
# 21   59052146.0           NaN              NaN             NaN
#
#    inat21_cls_name  inat21_cls_num   kingdom    phylum     class        order  \
# 13             NaN             NaN  Animalia  Chordata      Aves  Apodiformes
# 21             NaN             NaN  Animalia  Chordata  Reptilia     Squamata
#
#              family     genus   species          common  \
# 13      Trochilidae  Amazilia  franciae  andean emerald
# 21  Diplodactylidae   Bavayia   cyclura  Forest Bavayia
#
#                phylum_family
# 13      chordata_trochilidae
# 21  chordata_diplodactylidae

# %%
from datasets import load_dataset, IterableDataset
import pathlib, random, itertools, re

FAMILIES = {re.sub(r"^chordata_", "", f).lower()
            for f in targets if not f.startswith(".")}

N   = 10
OUT = pathlib.Path("tol10m_test"); OUT.mkdir(exist_ok=True)

# ---- streaming dataset (no repo_type!) ----
ds: IterableDataset = load_dataset(
        "imageomics/TreeOfLife-10M",
        split="train",          # or "train"
        streaming=True,       # enables HTTP streaming :contentReference[oaicite:7]{index=7}
        token=True            # use cached token (optional)
)

# ---- sample-on-the-fly ----
buffers, finished = {f: [] for f in FAMILIES}, set()
for ex in ds.shuffle(buffer_size=10_000, seed=42):      # random order :contentReference[oaicite:8]{index=8}
    fam = ex["family"].lower()
    if fam not in FAMILIES or fam in finished:
        continue

    buffers[fam].append(ex)
    if len(buffers[fam]) == N:
        finished.add(fam)
        (OUT/fam).mkdir(exist_ok=True)
        for e in buffers[fam]:
            e["jpg"].save(OUT/fam/f"{e['treeoflife_id']}.jpg")  # PIL image field :contentReference[oaicite:9]{index=9}
        print(f"✅  {fam}: {N} images saved")

    if len(finished) == len(FAMILIES):
        break
# Out:
# Resolving data files:   0%|          | 0/72 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 20
#      18 # ---- sample-on-the-fly ----
#      19 buffers, finished = {f: [] for f in FAMILIES}, set()
# ---> 20 for ex in ds.shuffle(buffer_size=10_000, seed=42):      # random order :contentReference[oaicite:8]{index=8}
#      21     fam = ex["family"].lower()
#      22     if fam not in FAMILIES or fam in finished:
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/datasets/iterable_dataset.py:2266, in IterableDataset.__iter__(self)
#    2263         yield formatter.format_row(pa_table)
#    2264     return
# -> 2266 for key, example in ex_iterable:
#    2267     # no need to format thanks to FormattedExamplesIterable
#    2268     yield example
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/datasets/iterable_dataset.py:1866, in FormattedExamplesIterable.__iter__(self)
#    1860 else:
#    1861     format_dict = (
#    1862         formatter.recursive_tensorize
#    1863         if isinstance(formatter, TensorFormatter)
#    1864         else None  # cast in case features is None
#    1865     )
# -> 1866     for key, example in self.ex_iterable:
#    1867         # don't apply feature types if already applied by ex_iterable (e.g. in case of chained with_format)
#    1868         if self.features and not self.ex_iterable.is_typed:
#    1869             example = _apply_feature_types_on_example(
#    1870                 example, self.features, token_per_repo_id=self.token_per_repo_id
#    1871             )
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/datasets/iterable_dataset.py:1535, in BufferShuffledExamplesIterable.__iter__(self)
#    1533 # this is the shuffle buffer that we keep in memory
#    1534 mem_buffer = []
# -> 1535 for x in self.ex_iterable:
#    1536     if len(mem_buffer) == buffer_size:  # if the buffer is full, pick and example from it
#    1537         i = next(indices_iterator)
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/datasets/iterable_dataset.py:265, in ShuffledDataSourcesExamplesIterable.__iter__(self)
#     261 for gen_kwags in islice(
#     262     _split_gen_kwargs(kwargs_with_shuffled_shards, max_num_jobs=self.num_shards), shard_idx_start, None
#     263 ):
#     264     shard_example_idx_start = self._state_dict["shard_example_idx"] if self._state_dict else 0
# --> 265     for key_example in islice(self.generate_examples_fn(**gen_kwags), shard_example_idx_start, None):
#     266         if self._state_dict:
#     267             self._state_dict["shard_example_idx"] += 1
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/datasets/packaged_modules/webdataset/webdataset.py:122, in WebDataset._generate_examples(self, tar_paths, tar_iterators)
#     120 all_field_names = list(self.info.features.keys())
#     121 for tar_idx, (tar_path, tar_iterator) in enumerate(zip(tar_paths, tar_iterators)):
# --> 122     for example_idx, example in enumerate(self._get_pipeline_from_tar(tar_path, tar_iterator)):
#     123         for field_name in all_field_names:
#     124             if field_name not in example:
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/datasets/packaged_modules/webdataset/webdataset.py:44, in WebDataset._get_pipeline_from_tar(cls, tar_path, tar_iterator)
#      42 current_example["__key__"] = example_key
#      43 current_example["__url__"] = tar_path
# ---> 44 current_example[field_name.lower()] = f.read()
#      45 if field_name.split(".")[-1] in SINGLE_FILE_COMPRESSION_EXTENSION_TO_PROTOCOL:
#      46     fs.write_bytes(filename, current_example[field_name.lower()])
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/tarfile.py:689, in _FileInFile.read(self, size)
#     687 if data:
#     688     self.fileobj.seek(offset + (self.position - start))
# --> 689     b = self.fileobj.read(length)
#     690     if len(b) != length:
#     691         raise ReadError("unexpected end of data")
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/tarfile.py:526, in _Stream.read(self, size)
#     524 """Return the next size number of bytes from the stream."""
#     525 assert size is not None
# --> 526 buf = self._read(size)
#     527 self.pos += len(buf)
#     528 return buf
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/tarfile.py:544, in _Stream._read(self, size)
#     542     self.buf = b""
#     543 else:
# --> 544     buf = self.fileobj.read(self.bufsize)
#     545     if not buf:
#     546         break
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/datasets/utils/file_utils.py:827, in _add_retries_to_file_obj_read_method.<locals>.read_with_retries(*args, **kwargs)
#     825 for retry in range(1, max_retries + 1):
#     826     try:
# --> 827         out = read(*args, **kwargs)
#     828         break
#     829     except (
#     830         aiohttp.client_exceptions.ClientError,
#     831         asyncio.TimeoutError,
#     832         requests.exceptions.ConnectionError,
#     833         requests.exceptions.Timeout,
#     834     ) as err:
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/huggingface_hub/hf_file_system.py:1013, in HfFileSystemFile.read(self, length)
#    1011     with self.fs.open(self.path, "rb", block_size=0) as f:  # block_size=0 enables fast streaming
#    1012         return f.read()
# -> 1013 return super().read(length)
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/fsspec/spec.py:2083, in AbstractBufferedFile.read(self, length)
#    2080 if length == 0:
#    2081     # don't even bother calling fetch
#    2082     return b""
# -> 2083 out = self.cache._fetch(self.loc, self.loc + length)
#    2085 logger.debug(
#    2086     "%s read: %i - %i %s",
#    2087     self,
#    (...)
#    2090     self.cache._log_stats(),
#    2091 )
#    2092 self.loc += len(out)
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/fsspec/caching.py:249, in ReadAheadCache._fetch(self, start, end)
#     247 end = min(self.size, end + self.blocksize)
#     248 self.total_requested_bytes += end - start
# --> 249 self.cache = self.fetcher(start, end)  # new block replaces old
#     250 self.start = start
#     251 self.end = self.start + len(self.cache)
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/huggingface_hub/hf_file_system.py:969, in HfFileSystemFile._fetch_range(self, start, end)
#     958 headers = {
#     959     "range": f"bytes={start}-{end - 1}",
#     960     **self.fs._api._build_hf_headers(),
#     961 }
#     962 url = hf_hub_url(
#     963     repo_id=self.resolved_path.repo_id,
#     964     revision=self.resolved_path.revision,
#    (...)
#     967     endpoint=self.fs.endpoint,
#     968 )
# --> 969 r = http_backoff(
#     970     "GET",
#     971     url,
#     972     headers=headers,
#     973     retry_on_status_codes=(500, 502, 503, 504),
#     974     timeout=constants.HF_HUB_DOWNLOAD_TIMEOUT,
#     975 )
#     976 hf_raise_for_status(r)
#     977 return r.content
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/huggingface_hub/utils/_http.py:310, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     307     kwargs["data"].seek(io_obj_initial_pos)
#     309 # Perform request and return if status_code is not in the retry list.
# --> 310 response = session.request(method=method, url=url, **kwargs)
#     311 if response.status_code not in retry_on_status_codes:
#     312     return response
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/requests/sessions.py:724, in Session.send(self, request, **kwargs)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/requests/sessions.py:724, in <listcomp>(.0)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/requests/sessions.py:265, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 265     resp = self.send(
#     266         req,
#     267         stream=stream,
#     268         timeout=timeout,
#     269         verify=verify,
#     270         cert=cert,
#     271         proxies=proxies,
#     272         allow_redirects=False,
#     273         **adapter_kwargs,
#     274     )
#     276     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     278     # extract redirect url, if any, for the next loop
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/urllib3/response.py:1066, in HTTPResponse.stream(self, amt, decode_content)
#    1064 else:
#    1065     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1066         data = self.read(amt=amt, decode_content=decode_content)
#    1068         if data:
#    1069             yield data
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/urllib3/response.py:955, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     952     if len(self._decoded_buffer) >= amt:
#     953         return self._decoded_buffer.get(amt)
# --> 955 data = self._raw_read(amt)
#     957 flush_decoder = amt is None or (amt != 0 and not data)
#     959 if not data and len(self._decoded_buffer) == 0:
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/urllib3/response.py:879, in HTTPResponse._raw_read(self, amt, read1)
#     876 fp_closed = getattr(self._fp, "closed", False)
#     878 with self._error_catcher():
# --> 879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880     if amt is not None and amt != 0 and not data:
#     881         # Platform-specific: Buggy versions of Python.
#     882         # Close the connection when no data is returned
#    (...)
#     887         # not properly close the connection in all cases. There is
#     888         # no harm in redundantly calling close.
#     889         self._fp.close()
#
# File ~/Library/Caches/pypoetry/virtualenvs/deeplearning2425-hoZFCvU9-py3.10/lib/python3.10/site-packages/urllib3/response.py:862, in HTTPResponse._fp_read(self, amt, read1)
#     859     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     860 else:
#     861     # StringIO doesn't like amt=None
# --> 862     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
len(targets)
# Out:
# 166
